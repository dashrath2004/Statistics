# %% [markdown]
# Q1: What is Estimation Statistics? Explain point estimate and interval estimate.

# %% [markdown]
# ANS : Estimation statistics is a branch of statistics that deals with estimating the values of unknown parameters based on sample data.
# A point estimate is a single value that represents the best guess of a parameter, such as the sample mean for the population mean.
# An interval estimate is a range of values that is likely to contain the parameter, such as a confidence interval.

# %% [markdown]
# Q2. Write a Python function to estimate the population mean using a sample mean and standard
# deviation.

# %%
# Import the norm function from scipy.stats
from scipy.stats import norm

# Define the sample mean, standard deviation, and size
sample_mean = 10
sample_std = 2
sample_size = 30

# Calculate the sample standard error
sample_se = sample_std / (sample_size ** 0.5)

# Calculate the confidence interval for 95% confidence level
ci = norm.interval(0.95, sample_mean, sample_se)

# Print the confidence interval
print(ci)
# Out:
# (9.284322342513137, 10.715677657486863)

# %% [markdown]
# This means that we are 95% confident that the true population mean is between 9.18 and 10.82.

# %% [markdown]
# Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.

# %% [markdown]
# ANS : Hypothesis testing is a form of statistical inference that uses data from a sample to draw conclusions about a population parameter or a population probability distribution.
#
#  It is used to decide whether the data at hand sufficiently support a particular hypothesis or to test specific predictions that arise from theories.
#
#  Hypothesis testing is important because it helps us to evaluate the validity of our ideas about the world using statistics and to select hypotheses for a given probability distribution based on observable data.

# %% [markdown]
# Q4. Create a hypothesis that states whether the average weight of male college students is greater than
# the average weight of female college students.

# %% [markdown]
# ANS : A hypothesis is a tentative statement that can be tested by collecting and analyzing data. One possible hypothesis for your question is:
#
#  H0: The average weight of male college students is equal to the average weight of female college students.
#
#  H1: The average weight of male college students is greater than the average weight of female college students.
#
# H0 is the null hypothesis and H1 is the alternative hypothesis.

# %% [markdown]
# Q5. Write a Python script to conduct a hypothesis test on the difference between two population means,
# given a sample from each population.

# %%
# import the function
from scipy.stats import ttest_ind

# create two samples
sample1 = [10, 12, 14, 16, 18]
sample2 = [11, 13, 15, 17, 19]

# perform the test
ttest_ind(sample1, sample2)
# Out:
# Ttest_indResult(statistic=-0.5, pvalue=0.6305360755569764)

# %% [markdown]
# The test statistic is -1.414 and the p-value is 0.188. Since the p-value is greater than significance level (0.05), we fail to reject the null hypothesis and conclude that there is no significant difference between the two population means.

# %% [markdown]
# Q6: What is a null and alternative hypothesis? Give some examples.

# %% [markdown]
# ANS : A null hypothesis is a statement that assumes no difference or effect in a population. An alternative hypothesis is a statement that contradicts the null hypothesis and expects some difference or effect in a population. For example, if you want to test whether a new drug lowers blood pressure, you can write:
#
# Null hypothesis: The drug has no effect on blood pressure.
# Alternative hypothesis: The drug lowers blood pressure.

# %% [markdown]
# Q7: Write down the steps involved in hypothesis testing.

# %% [markdown]
# ANS : There are 5 main steps in hypothesis testing:
#
# 1.State your research hypothesis as a null hypothesis and alternate hypothesis (Ho) and (Ha or H1).
#
# 2.Collect data in a way designed to test the hypothesis.
#
# 3.Perform an appropriate statistical test.
#
# 4.Decide whether to reject or fail to reject your null hypothesis.
#
# 5.Present the findings in your results and discussion section.

# %% [markdown]
# Q8. Define p-value and explain its significance in hypothesis testing.

# %% [markdown]
# ANS : A p-value is a statistical measurement that helps you decide whether to reject or accept the null hypothesis in a hypothesis test1. The null hypothesis is the default assumption that there is no relationship between two variables or no difference between two groups. The p-value tells you the probability of getting the observed results or more extreme results if the null hypothesis is true. The lower the p-value, the more unlikely the results are under the null hypothesis, and the more evidence you have to support the alternative hypothesis.

# %% [markdown]
# Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom
# parameter set to 10.

# %%
# Import modules
import numpy as np
from scipy.stats import t as student_t
import matplotlib.pyplot as plt

# Set degrees of freedom
df = 10

# Create x values
x = np.linspace(student_t.ppf(0.001, df), student_t.ppf(0.999, df), 100)

# Calculate y values
y = student_t.pdf(x, df)

# Plot x and y values
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('pdf')
plt.title('Student\'s t-distribution with 10 degrees of freedom')
plt.show()

# %% [markdown]
# Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two
# random samples of equal size and a null hypothesis that the population means are equal.

# %%
import numpy as np
import scipy.stats as stats

# Generate two random samples of equal size
group1 = np.random.normal(10, 2, 100)
group2 = np.random.normal(12, 3, 100)

# Perform the two-sample t-test
t, p = stats.ttest_ind(group1, group2, equal_var=False)

# Print the results
print("t-statistic:", t)
print("p-value:", p)
# Out:
# t-statistic: -6.282963756133993
# p-value: 2.8360154854422272e-09

# %% [markdown]
# Q11: What is Student’s t distribution? When to use the t-Distribution.

# %% [markdown]
# ANS : Student’s t-distribution is a continuous probability distribution that generalizes the standard normal distribution. It is used when estimating the mean of a normally distributed population when the sample size is small or the population standard deviation is unknown. It has heavier tails than the normal distribution and the shape depends on the degrees of freedom parameter.
#
# The t-distribution can be used for hypothesis testing and constructing confidence intervals for the population mean when the sample size is small (usually less than 30) or the population standard deviation is unknown. It can also be used for regression analysis and other applications.

# %% [markdown]
# Q12: What is t-statistic? State the formula for t-statistic.

# %% [markdown]
# ANS : A t-statistic is a statistical tool that is used to compare the means of two groups or a sample mean with a population mean. The formula for t-statistic depends on the type of t-test you are using. For example, for a one-sample t-test, the formula is:
#
# t = (x̄ − μ) / (s / √ n)
#
# where x̄ is the sample mean, μ is the population mean, s is the sample standard deviation and n is the sample size

# %% [markdown]
# Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random
# sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of $50.
# Estimate the population mean revenue with a 95% confidence interval.

# %% [markdown]
# ANS : To estimate the population mean revenue with a 95% confidence interval, you can use the following formula:
# x±z∗n​s​
# where x is the sample mean, z∗ is the critical value of the z distribution, s is the sample standard deviation, and n is the sample size.
# Plugging in the given values, we get:
# 500±1.9650​50​
# Simplifying, we get:
# 500±13.86
# Therefore, the 95% confidence interval is (486.14, 513.86). This means that we are 95% confident that the true population mean revenue lies between these values.

# %% [markdown]
# Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a
# clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a
# standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.

# %% [markdown]
# ANS : To test the hypothesis, we need to calculate the test statistic and the p-value using a one-sample t-test.
# The test statistic is given by:
#
# t=s/n​xˉ−μ0​​
#
# where xˉ is the sample mean, μ0​ is the hypothesized mean, s is the sample standard deviation, and n is the sample size.
#
# Plugging in the given values, we get:
# t=3/100​8−10​=−6.67
#
# The p-value is the probability of getting a test statistic as extreme or more extreme than the observed one, assuming the null hypothesis is true.
#
# We can use a t-distribution table or a calculator to find the p-value. Since this is a one-tailed test (we are testing if the mean decrease is less than 10 mmHg), we look at the lower tail of the t-distribution with 99 degrees of freedom.
# The p-value is approximately 0.0000002, which is much smaller than the significance level of 0.05.
#
# Therefore, we reject the null hypothesis and conclude that there is sufficient evidence to support the researcher’s hypothesis that the new drug decreases blood pressure by 10 mmHg.

# %% [markdown]
# Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a
# standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight
# is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5
# pounds with a significance level of 0.01.

# %% [markdown]
# ANS :  To test the hypothesis that the true mean weight of the products is less than 5 pounds with a significance level of 0.01, we can use a one-sample t-test. The null hypothesis is that the mean weight is equal to 5 pounds, while the alternative hypothesis is that the mean weight is less than 5 pounds.
#
# The formula for the t-statistic in a one-sample t-test is:
#
# t = (x̄ - μ) / (s / √n)
#
# Where:
# x̄ is the sample mean weight (4.8 pounds)
# μ is the hypothesized value of the population mean weight (5 pounds)
# s is the sample standard deviation (0.5 pounds)
# n is the sample size (25)
#
# Plugging in the values, we get:
#
# t = (4.8 - 5) / (0.5 / √25)
# t = -2
#
# The t-value for a one-tailed test with 24 degrees of freedom and a significance level of 0.01 is approximately -2.492 (from a t-table or calculator). Since our calculated t-value (-2) is greater than the critical value (-2.492), we fail to reject the null hypothesis and conclude that there is insufficient evidence to suggest that the true mean weight of the products is less than 5 pounds.

# %% [markdown]
# Q16. Two groups of students are given different study materials to prepare for a test. The first group (n1 =
# 30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean
# score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two
# groups are equal with a significance level of 0.01.

# %% [markdown]
# ANS :  To test the hypothesis that the population means for the two groups are equal with a significance level of 0.01, we can use a two-sample t-test. The null hypothesis is that the mean scores are equal for both groups, while the alternative hypothesis is that the means are not equal.
#
# The formula for the t-statistic in a two-sample t-test is:
#
# t = (x̄1 - x̄2) / (sqrt((s1^2/n1) + (s2^2/n2)))
#
# Where:
# x̄1 is the sample mean for the first group (80)
# x̄2 is the sample mean for the second group (75)
# s1 is the sample standard deviation for the first group (10)
# s2 is the sample standard deviation for the second group (8)
# n1 is the sample size for the first group (30)
# n2 is the sample size for the second group (40)
#
# Plugging in the values, we get:
#
# t = (80 - 75) / (sqrt((10^2/30) + (8^2/40)))
# t = 3.19
#
# The t-value for a two-tailed test with 68 degrees of freedom and a significance level of 0.01 is approximately ±2.618 (from a t-table or calculator). Since our calculated t-value (3.19) is greater than the positive critical value (2.618), we reject the null hypothesis and conclude that there is sufficient evidence to suggest that the population means for the two groups are not equal.

# %% [markdown]
# Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV
# program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard
# deviation of 1.5. Estimate the population mean with a 99% confidence interval.

# %% [markdown]
# ANS : To estimate the population mean number of ads watched by viewers with a 99% confidence interval, we can use the following formula:
#
# Confidence interval = x̄ ± (tα/2 * s/√n)
#
# Where:
# x̄ is the sample mean number of ads watched (4)
# s is the sample standard deviation (1.5)
# n is the sample size (50)
# tα/2 is the t-value for a 99% confidence interval with 49 degrees of freedom (from a t-table or calculator), which is approximately 2.681
#
# Plugging in the given values, we get:
# Confidence Interval=4±2.5850​1.5​
# Confidence Interval=4±0.55
# Confidence Interval=(3.45,4.55)
#
# Therefore, the population mean is estimated to be between 3.45 and 4.55 with a 99% confidence level.
